# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DS1621.csv")

# %%
df
# Out:
#            date  product  price
# 0    10.07.2021  DS1621+  914.0
# 1    11.07.2021  DS1621+  914.0
# 2    12.07.2021  DS1621+  914.0
# 3    13.07.2021  DS1621+  914.0
# 4    14.07.2021  DS1621+  919.0
# ..          ...      ...    ...
# 477  30.10.2022  DS1621+  940.0
# 478  31.10.2022  DS1621+  940.0
# 479  01.11.2022  DS1621+  940.0
# 480  02.11.2022  DS1621+  940.0
# 481  03.11.2022  DS1621+  940.0
#
# [482 rows x 3 columns]

# %%
x = df["price"]
y = df["date"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     482 non-null    object
#  1   product  481 non-null    object
#  2   price    481 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 11.4+ KB

# %%
df["date"] = pd.to_datetime(df["date"])
# Out:
# /var/folders/v_/xssbct5x2dz7cv5vyj7syts40000gn/T/ipykernel_2105/3228555721.py:1: UserWarning: Parsing '13.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"])
# /var/folders/v_/xssbct5x2dz7cv5vyj7syts40000gn/T/ipykernel_2105/3228555721.py:1: UserWarning: Parsing '14.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"])
# /var/folders/v_/xssbct5x2dz7cv5vyj7syts40000gn/T/ipykernel_2105/3228555721.py:1: UserWarning: Parsing '15.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df["date"] = pd.to_datetime(df["date"])
# /var/folders/v_/xssbct5x2dz7cv5vyj7syts40000gn/T/ipykernel_2105/3228555721.py:1: UserWarning: Parsing '16.07.2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     482 non-null    datetime64[ns]
#  1   product  481 non-null    object
#  2   price    481 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 11.4+ KB

# %%
# make data
x = df["date"]
y = df["price"]

# %%
plt.figure(figsize=(12,8))
df["price"].plot()
# Out:
# <AxesSubplot:>
